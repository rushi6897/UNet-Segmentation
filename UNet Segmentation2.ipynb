# %%
# importing the necessary libraries 
import torch
import torch.nn as nn
import gc
import torch
import cv2
import numpy as np
import matplotlib.pyplot as plt

torch.cuda.empty_cache()
# del variable #delete unnecessary variables 
gc.collect()

# Device configuration
device = torch.device('cuda')

# %%
# loading the Validation Dataset
dir_val =r"ValidationImages"
import os
validation_images=[] 
val_names = []
for img_name in os.listdir(dir_val):
#     print(img_name)
    val_names.append(img_name)
    imgp = os.path.join(dir_val,img_name)
    img = cv2.imread(imgp,cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (256,256))
    validation_images.append(img)

print("validation_images: ",len(validation_images))
    
    
val_mask = r"ValidationMasks"
vmask_img=[] 
vmask_names = []
for mask_name in os.listdir(val_mask):
#     print(mask_name)
    vmask_names.append(vmask_names)
    maskp = os.path.join(val_mask,mask_name)
    mask = cv2.imread(maskp,0)
    mask = cv2.resize(mask, (256,256))
#     print(mask.shape)
    vmask_img.append(mask)
    
print("validation_Masks: ",len(vmask_img)) 
    
img_H=256
img_W=256
validation_images = np.array(validation_images)
print(validation_images.shape)
validation_images_reshp = np.reshape(validation_images,(-1,1,img_H,img_W))
print(validation_images_reshp.shape)

vmask_img = np.array(vmask_img)
print(vmask_img.shape)
vmask_img_reshp = np.reshape(vmask_img,(-1,1,img_H,img_W))
print(vmask_img_reshp.shape)

validation_images_reshp=torch.from_numpy(validation_images_reshp)
print(validation_images_reshp.size())
vmask_img_reshp=torch.from_numpy(vmask_img_reshp)
print(vmask_img_reshp.size()) 

# validation_images_reshp  vmask_img_reshp
# Out:
# validation_images:  15
# validation_Masks:  15
# (15, 256, 256)
# (15, 1, 256, 256)
# (15, 256, 256)
# (15, 1, 256, 256)
# torch.Size([15, 1, 256, 256])
# torch.Size([15, 1, 256, 256])

# %%
# Validation Data Loader 
batch_size =5
  
valImg_loader = torch.utils.data.DataLoader(validation_images_reshp, batch_size=batch_size
                                          )

ValMask_loader = torch.utils.data.DataLoader(vmask_img_reshp, batch_size=batch_size
                                         )

# valImg_loader ValMask_loader

# %%
""" Convolutional block:
    It follows a two 3x3 convolutional layer, each followed by a batch normalization and a relu activation.
"""
# in_c = no of input channels out_c= no of output channels  padding=1 means "same"
class conv_block(nn.Module):
    def __init__(self, in_c, out_c):
        super().__init__()

        self.conv1 = nn.Conv2d(in_c, out_c, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(out_c)

        self.conv2 = nn.Conv2d(out_c, out_c, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(out_c)

        self.relu = nn.ReLU()

    def forward(self, inputs):
        x = self.conv1(inputs)
        # print("conv_block1: ", x.shape)
        x = self.bn1(x)
        x = self.relu(x)

        x = self.conv2(x)
        # print("conv_block2: ", x.shape)
        x = self.bn2(x)
        x = self.relu(x)

        return x

""" Encoder block:
    It consists of an conv_block followed by a max pooling.
    Here the number of filters doubles and the height and width half after every block.
"""
class encoder_block(nn.Module):
    def __init__(self, in_c, out_c):
        super().__init__()

        self.conv = conv_block(in_c, out_c)
        self.pool = nn.MaxPool2d((2, 2))

    def forward(self, inputs):
        x = self.conv(inputs)
        p = self.pool(x)

        return x, p

""" Decoder block:
    The decoder block begins with a transpose convolution, followed by a concatenation with the skip
    connection from the encoder block. Next comes the conv_block.
    Here the number filters decreases by half and the height and width doubles.
"""
class decoder_block(nn.Module):
    def __init__(self, in_c, out_c):
        super().__init__()

        self.up = nn.ConvTranspose2d(in_c, out_c, kernel_size=2, stride=2, padding=0)
        self.conv = conv_block(out_c+out_c, out_c)

    def forward(self, inputs, skip):
        x = self.up(inputs)
        # print("decoder x1.shape: ",x.shape)
        x = torch.cat([x, skip], axis=1)
        # print("decoder x2.shape: ",x.shape)
        x = self.conv(x)
        # print("decoder x2.shape: ",x.shape)

        return x
    
class build_unet(nn.Module):
    def __init__(self):
        super().__init__()

        """ Encoder """
        self.e1 = encoder_block(1, 64)
        self.e2 = encoder_block(64, 128)
        self.e3 = encoder_block(128, 256)
        self.e4 = encoder_block(256, 512)

        """ Bottleneck """
        self.b = conv_block(512, 1024)

        """ Decoder """
        self.d1 = decoder_block(1024, 512)
        self.d2 = decoder_block(512, 256)
        self.d3 = decoder_block(256, 128)
        self.d4 = decoder_block(128, 64)

        """ Classifier """
        self.outputs = nn.Conv2d(64, 1, kernel_size=1, padding=0)

    def forward(self, inputs):
        """ Encoder """
        # print("inputs.shape: ",inputs.shape)
        s1, p1 = self.e1(inputs)
        # print("s1.shape: ",s1.shape, "p1.shape: ",p1.shape)
        s2, p2 = self.e2(p1)
        # print("s2.shape: ",s2.shape, "p2.shape: ",p2.shape)
        s3, p3 = self.e3(p2)
        # print("s3.shape: ",s3.shape, "p3.shape: ",p3.shape)
        s4, p4 = self.e4(p3)
        # print("s4.shape: ",s4.shape, "p4.shape: ",p4.shape)

        """ Bottleneck """
        b = self.b(p4)
        # print("botlleneck shape :",b.shape)

        """ Decoder """
        d1 = self.d1(b, s4)
        d2 = self.d2(d1, s3)
        d3 = self.d3(d2, s2)
        d4 = self.d4(d3, s1)
        # print(d4.shape)
        """ Classifier """
        outputs = self.outputs(d4)

        return outputs

# %%
# Hyperparameters 
size = (256, 256)
num_epochs =120
lr = 0.0001
model = build_unet().to(device)
criterion = nn.BCEWithLogitsLoss()

# optimizer = torch.optim.SGD(model.parameters(), lr=lr)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# criterion = nn.MSELoss()
# loss = torch.sqrt(criterion(x, y))

# %%
# Loading training images and mask with the help of dataloader
from torch.utils.data import Dataset

import os
import torch
import pandas as pd
from skimage import io, transform
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import cv2

class DatasetUnet(Dataset):
    """Face Landmarks dataset."""

    def __init__(self, img_path, mask_path, transform=None):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.root_Img = img_path
        self.root_Mask = mask_path
        
        self.img_dir = os.listdir(img_path)
        self.transform = transform

    def __len__(self):
        return len(self.img_dir)

    def __getitem__(self, idx):
    
        img_name = self.img_dir[idx]
#         print(img_name)
        img = cv2.imread(os.path.join(self.root_Img, img_name),0)
        img = cv2.resize(img, (256,256))
        img =np.reshape(img,(1,256,256))
        img=torch.from_numpy(img)
        
        mask= cv2.imread(os.path.join(self.root_Mask, img_name),0) # here image_name and mask name are same 
        mask = cv2.resize(mask, (256,256))
        mask = np.reshape(mask,(1,256,256))
        mask=torch.from_numpy(mask)
        return img, mask

# %%
img_path = r"Train_Images"
mask_path = r"Train_Masks"
batch_size = 16
obj = DatasetUnet(img_path, mask_path)
dataloader = DataLoader(obj,batch_size=batch_size,
                        shuffle=True, num_workers=0)
print(obj.__len__())
# Out:
# 245

# %%
train_losses = []
validation_losses=[]
vl =10
for epoch in range(num_epochs):
    epoch_loss = []
    for i, (images, labels) in enumerate(dataloader):
        images = (images.float()/255.0).to(device)
        labels = (labels.float()/255.0).to(device)
        # Forward pass
        outputs = model(images)
        # print(outputs.shape)
        loss = criterion(outputs, labels)
        # loss = torch.sqrt(criterion(outputs, labels))

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        epoch_loss.append(loss.cpu().data.numpy())
#         valImg_loader ValMask_loader
        # validation data
    val_losses = []
    for j, (val_images, val_labels) in enumerate(zip(valImg_loader,ValMask_loader)):
        pred_val = model((val_images.float()/255.0).to(device))
        pred_masks = (val_labels.float()/255.0).to(device)
        val_loss = criterion(pred_val, pred_masks)
#         val_loss = torch.sqrt(criterion(pred_val, pred_masks))
        val_losses.append(val_loss.cpu().data.numpy())
        

    mean_val_loss = np.array(val_losses).mean()
        
    train_losses.append(loss)
    mean_train_loss = np.array(epoch_loss).mean()
    validation_losses.append(mean_val_loss)
    
#     code to save the best model
    if mean_val_loss< vl:
        print(f"Best Model Saved at validation loss :{mean_val_loss:.4f}")
        PATH = './BestModel.pth'
        torch.save(model.state_dict(), PATH)
        vl = mean_val_loss

    print (f'Epoch [{epoch+1}/{num_epochs}], Epoch Loss: {mean_train_loss.item():.4f}, Val_loss:{mean_val_loss:.4f} ')
        
print('Finished Training')
PATH = './CrackSegment.pth'
torch.save(model.state_dict(), PATH)
# Out:
# Best Model Saved at validation loss :0.5385
# Epoch [1/120], Epoch Loss: 0.6247, Val_loss:0.5385
# Best Model Saved at validation loss :0.4493
# Epoch [2/120], Epoch Loss: 0.4718, Val_loss:0.4493
# Best Model Saved at validation loss :0.4175
# Epoch [3/120], Epoch Loss: 0.4185, Val_loss:0.4175
# Best Model Saved at validation loss :0.3954
# Epoch [4/120], Epoch Loss: 0.3915, Val_loss:0.3954
# Best Model Saved at validation loss :0.3866
# Epoch [5/120], Epoch Loss: 0.3720, Val_loss:0.3866
# Best Model Saved at validation loss :0.3697
# Epoch [6/120], Epoch Loss: 0.3586, Val_loss:0.3697
# Best Model Saved at validation loss :0.3652
# Epoch [7/120], Epoch Loss: 0.3474, Val_loss:0.3652
# Best Model Saved at validation loss :0.3509
# Epoch [8/120], Epoch Loss: 0.3363, Val_loss:0.3509
# Best Model Saved at validation loss :0.3432
# Epoch [9/120], Epoch Loss: 0.3321, Val_loss:0.3432
# Best Model Saved at validation loss :0.3360
# Epoch [10/120], Epoch Loss: 0.3217, Val_loss:0.3360
# Epoch [11/120], Epoch Loss: 0.3147, Val_loss:0.3427
# Best Model Saved at validation loss :0.3187
# Epoch [12/120], Epoch Loss: 0.3074, Val_loss:0.3187
# Best Model Saved at validation loss :0.3109
# Epoch [13/120], Epoch Loss: 0.3001, Val_loss:0.3109
# Best Model Saved at validation loss :0.3022
# Epoch [14/120], Epoch Loss: 0.2903, Val_loss:0.3022
# Best Model Saved at validation loss :0.2973
# Epoch [15/120], Epoch Loss: 0.2836, Val_loss:0.2973
# Best Model Saved at validation loss :0.2927
# Epoch [16/120], Epoch Loss: 0.2765, Val_loss:0.2927
# Epoch [17/120], Epoch Loss: 0.2752, Val_loss:0.2999
# Epoch [18/120], Epoch Loss: 0.2729, Val_loss:0.2931
# Best Model Saved at validation loss :0.2753
# Epoch [19/120], Epoch Loss: 0.2651, Val_loss:0.2753
# Best Model Saved at validation loss :0.2673
# Epoch [20/120], Epoch Loss: 0.2579, Val_loss:0.2673
# Best Model Saved at validation loss :0.2663
# Epoch [21/120], Epoch Loss: 0.2601, Val_loss:0.2663
# Best Model Saved at validation loss :0.2598
# Epoch [22/120], Epoch Loss: 0.2477, Val_loss:0.2598
# Epoch [23/120], Epoch Loss: 0.2467, Val_loss:0.2691
# Epoch [24/120], Epoch Loss: 0.2378, Val_loss:0.2624
# Best Model Saved at validation loss :0.2442
# Epoch [25/120], Epoch Loss: 0.2318, Val_loss:0.2442
# Best Model Saved at validation loss :0.2415
# Epoch [26/120], Epoch Loss: 0.2276, Val_loss:0.2415
# Best Model Saved at validation loss :0.2344
# Epoch [27/120], Epoch Loss: 0.2213, Val_loss:0.2344
# Epoch [28/120], Epoch Loss: 0.2198, Val_loss:0.2374
# Best Model Saved at validation loss :0.2250
# Epoch [29/120], Epoch Loss: 0.2152, Val_loss:0.2250
# Best Model Saved at validation loss :0.2214
# Epoch [30/120], Epoch Loss: 0.2106, Val_loss:0.2214
# Best Model Saved at validation loss :0.2169
# Epoch [31/120], Epoch Loss: 0.2045, Val_loss:0.2169
# Epoch [32/120], Epoch Loss: 0.1996, Val_loss:0.2201
# Best Model Saved at validation loss :0.2089
# Epoch [33/120], Epoch Loss: 0.1977, Val_loss:0.2089
# Epoch [34/120], Epoch Loss: 0.1954, Val_loss:0.2119
# Best Model Saved at validation loss :0.2002
# Epoch [35/120], Epoch Loss: 0.1917, Val_loss:0.2002
# Epoch [36/120], Epoch Loss: 0.1857, Val_loss:0.2051
# Best Model Saved at validation loss :0.1957
# Epoch [37/120], Epoch Loss: 0.1819, Val_loss:0.1957
# Epoch [38/120], Epoch Loss: 0.1789, Val_loss:0.1990
# Best Model Saved at validation loss :0.1948
# Epoch [39/120], Epoch Loss: 0.1758, Val_loss:0.1948
# Best Model Saved at validation loss :0.1828
# Epoch [40/120], Epoch Loss: 0.1739, Val_loss:0.1828
# Epoch [41/120], Epoch Loss: 0.1698, Val_loss:0.1852
# Best Model Saved at validation loss :0.1818
# Epoch [42/120], Epoch Loss: 0.1673, Val_loss:0.1818
# Best Model Saved at validation loss :0.1712
# Epoch [43/120], Epoch Loss: 0.1640, Val_loss:0.1712
# Best Model Saved at validation loss :0.1705
# Epoch [44/120], Epoch Loss: 0.1608, Val_loss:0.1705
# Best Model Saved at validation loss :0.1693
# Epoch [45/120], Epoch Loss: 0.1622, Val_loss:0.1693
# Best Model Saved at validation loss :0.1640
# Epoch [46/120], Epoch Loss: 0.1574, Val_loss:0.1640
# Epoch [47/120], Epoch Loss: 0.1557, Val_loss:0.1692
# Best Model Saved at validation loss :0.1589
# Epoch [48/120], Epoch Loss: 0.1524, Val_loss:0.1589
# Epoch [49/120], Epoch Loss: 0.1484, Val_loss:0.1591
# Best Model Saved at validation loss :0.1580
# Epoch [50/120], Epoch Loss: 0.1479, Val_loss:0.1580
# Best Model Saved at validation loss :0.1526
# Epoch [51/120], Epoch Loss: 0.1502, Val_loss:0.1526
# Epoch [52/120], Epoch Loss: 0.1431, Val_loss:0.1543
# Best Model Saved at validation loss :0.1511
# Epoch [53/120], Epoch Loss: 0.1411, Val_loss:0.1511
# Best Model Saved at validation loss :0.1447
# Epoch [54/120], Epoch Loss: 0.1408, Val_loss:0.1447
# Best Model Saved at validation loss :0.1436
# Epoch [55/120], Epoch Loss: 0.1384, Val_loss:0.1436
# Epoch [56/120], Epoch Loss: 0.1359, Val_loss:0.1496
# Best Model Saved at validation loss :0.1424
# Epoch [57/120], Epoch Loss: 0.1323, Val_loss:0.1424
# Best Model Saved at validation loss :0.1410
# Epoch [58/120], Epoch Loss: 0.1302, Val_loss:0.1410
# Best Model Saved at validation loss :0.1389
# Epoch [59/120], Epoch Loss: 0.1304, Val_loss:0.1389
# Epoch [60/120], Epoch Loss: 0.1262, Val_loss:0.1394
# Best Model Saved at validation loss :0.1370
# Epoch [61/120], Epoch Loss: 0.1253, Val_loss:0.1370
# Best Model Saved at validation loss :0.1351
# Epoch [62/120], Epoch Loss: 0.1221, Val_loss:0.1351
# Best Model Saved at validation loss :0.1322
# Epoch [63/120], Epoch Loss: 0.1199, Val_loss:0.1322
# Best Model Saved at validation loss :0.1302
# Epoch [64/120], Epoch Loss: 0.1215, Val_loss:0.1302
# Best Model Saved at validation loss :0.1254
# Epoch [65/120], Epoch Loss: 0.1180, Val_loss:0.1254
# Best Model Saved at validation loss :0.1237
# Epoch [66/120], Epoch Loss: 0.1174, Val_loss:0.1237
# Epoch [67/120], Epoch Loss: 0.1153, Val_loss:0.1320
# Best Model Saved at validation loss :0.1222
# Epoch [68/120], Epoch Loss: 0.1182, Val_loss:0.1222
# Best Model Saved at validation loss :0.1191
# Epoch [69/120], Epoch Loss: 0.1148, Val_loss:0.1191
# Epoch [70/120], Epoch Loss: 0.1105, Val_loss:0.1229
# Epoch [71/120], Epoch Loss: 0.1083, Val_loss:0.1241
# Epoch [72/120], Epoch Loss: 0.1066, Val_loss:0.1214
# Best Model Saved at validation loss :0.1169
# Epoch [73/120], Epoch Loss: 0.1052, Val_loss:0.1169
# Epoch [74/120], Epoch Loss: 0.1053, Val_loss:0.1183
# Best Model Saved at validation loss :0.1108
# Epoch [75/120], Epoch Loss: 0.1047, Val_loss:0.1108
# Epoch [76/120], Epoch Loss: 0.1044, Val_loss:0.1179
# Best Model Saved at validation loss :0.1107
# Epoch [77/120], Epoch Loss: 0.1035, Val_loss:0.1107
# Epoch [78/120], Epoch Loss: 0.1027, Val_loss:0.1139
# Epoch [79/120], Epoch Loss: 0.1006, Val_loss:0.1183
# Epoch [80/120], Epoch Loss: 0.0971, Val_loss:0.1146
# Best Model Saved at validation loss :0.1076
# Epoch [81/120], Epoch Loss: 0.0947, Val_loss:0.1076
# Best Model Saved at validation loss :0.1071
# Epoch [82/120], Epoch Loss: 0.0925, Val_loss:0.1071
# Best Model Saved at validation loss :0.1037
# Epoch [83/120], Epoch Loss: 0.0927, Val_loss:0.1037
# Epoch [84/120], Epoch Loss: 0.0909, Val_loss:0.1090
# Best Model Saved at validation loss :0.1023
# Epoch [85/120], Epoch Loss: 0.0919, Val_loss:0.1023
# Epoch [86/120], Epoch Loss: 0.0917, Val_loss:0.1107
# Epoch [87/120], Epoch Loss: 0.0911, Val_loss:0.1062
# Best Model Saved at validation loss :0.0991
# Epoch [88/120], Epoch Loss: 0.0891, Val_loss:0.0991
# Best Model Saved at validation loss :0.0984
# Epoch [89/120], Epoch Loss: 0.0873, Val_loss:0.0984
# Epoch [90/120], Epoch Loss: 0.0849, Val_loss:0.0994
# Epoch [91/120], Epoch Loss: 0.0838, Val_loss:0.1053
# Best Model Saved at validation loss :0.0963
# Epoch [92/120], Epoch Loss: 0.0827, Val_loss:0.0963
# Epoch [93/120], Epoch Loss: 0.0827, Val_loss:0.0985
# Epoch [94/120], Epoch Loss: 0.0800, Val_loss:0.1067
# Epoch [95/120], Epoch Loss: 0.0816, Val_loss:0.1057
# Epoch [96/120], Epoch Loss: 0.0794, Val_loss:0.0996
# Best Model Saved at validation loss :0.0949
# Epoch [97/120], Epoch Loss: 0.0800, Val_loss:0.0949
# Epoch [98/120], Epoch Loss: 0.0915, Val_loss:0.1000
# Epoch [99/120], Epoch Loss: 0.0951, Val_loss:0.1050
# Best Model Saved at validation loss :0.0921
# Epoch [100/120], Epoch Loss: 0.0878, Val_loss:0.0921
# Epoch [101/120], Epoch Loss: 0.0793, Val_loss:0.0949
# Best Model Saved at validation loss :0.0909
# Epoch [102/120], Epoch Loss: 0.0758, Val_loss:0.0909
# Epoch [103/120], Epoch Loss: 0.0742, Val_loss:0.1007
# Epoch [104/120], Epoch Loss: 0.0725, Val_loss:0.1003
# Epoch [105/120], Epoch Loss: 0.0737, Val_loss:0.0964
# Epoch [106/120], Epoch Loss: 0.0742, Val_loss:0.0924
# Epoch [107/120], Epoch Loss: 0.0725, Val_loss:0.0929
# Epoch [108/120], Epoch Loss: 0.0693, Val_loss:0.0921
# Epoch [109/120], Epoch Loss: 0.0675, Val_loss:0.0992
# Best Model Saved at validation loss :0.0888
# Epoch [110/120], Epoch Loss: 0.0675, Val_loss:0.0888
# Epoch [111/120], Epoch Loss: 0.0671, Val_loss:0.0965
# Epoch [112/120], Epoch Loss: 0.0659, Val_loss:0.0940
# Epoch [113/120], Epoch Loss: 0.0645, Val_loss:0.0944
# Epoch [114/120], Epoch Loss: 0.0637, Val_loss:0.1013
# Epoch [115/120], Epoch Loss: 0.0616, Val_loss:0.1035
# Epoch [116/120], Epoch Loss: 0.0619, Val_loss:0.0999
# Epoch [117/120], Epoch Loss: 0.0612, Val_loss:0.0994
# Epoch [118/120], Epoch Loss: 0.0638, Val_loss:0.0937
# Epoch [119/120], Epoch Loss: 0.0623, Val_loss:0.1042
# Epoch [120/120], Epoch Loss: 0.0617, Val_loss:0.1119
# Finished Training

# %%
from sklearn.metrics import precision_score,recall_score,f1_score

# %%
# Dice similarity function
def dice(pred, true, k = True):
    intersection = np.sum(pred[true==k]) * 2.0
    dice = intersection / (np.sum(pred) + np.sum(true))
    return dice

# dice_score = dice(y_p, y_t, k = True) #255 in my case, can be 1 
# print ("Dice Similarity: {}".format(dice_score))

# %%
def Y_Pred(input_img_path):
    test_img=[]
    print(os.listdir(input_img_path))
    for img_name in os.listdir(input_img_path):
        imgp = os.path.join(input_img_path,img_name)
        img = cv2.imread(imgp,cv2.IMREAD_GRAYSCALE)
        img = cv2.resize(img, (256,256))
        test_img.append(img)

    test_img = np.array(test_img)
    # print(test_img.shape)
    test_imgR = np.reshape(test_img,(-1,1,img_H,img_W))
    # print(test_imgR.shape)
    test_imgR=torch.from_numpy(test_imgR)/255.0
    test_imgR=test_imgR.float()

    # giving test image input to the model
    predicted = model(test_imgR) 
    predicted =np.where(predicted > 0.5, 1, 0)   
    return np.array(predicted)

# %%
test_Maskdirectory =r"Test_Masks"

def Y_true(mask_path):
    # print("Y_True function: ")
    mask_img = []
    print(os.listdir(mask_path))
    for img_name in os.listdir(mask_path):
        imgp = os.path.join(mask_path,img_name)
        img = cv2.imread(imgp,cv2.IMREAD_GRAYSCALE)
        img = cv2.resize(img, (256,256))
        mask_img.append(img)

    mask_img = np.array(mask_img)
    # print(mask_img.shape)
    mask_img = np.reshape(mask_img,(-1,1,img_H,img_W))
    # print(mask_img.shape)
    mask_img=torch.from_numpy(mask_img)/255.0
    mask_img=mask_img.float()
    mask_img=np.array(mask_img)
    mask_img =np.where(mask_img > 0.5, 1, 0)
    return mask_img

y_t = Y_true(test_Maskdirectory)
y_t.shape
# Out:
# ['119.jpg', '79.jpg', '106.jpg', '12.jpg', '54.jpg', '134.jpg', '124.jpg', '41.jpg', '75.jpg', '1.jpg']
# (10, 1, 256, 256)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,jaccard_score
# Various Metrics for evaluating the segmentation results 
def EvaluationOfSegmentation(test_img_path, test_mask_path):
    y_p = Y_Pred(test_img_path).flatten()
    y_t = Y_true(test_mask_path).flatten()
    print()
    print(" Various Evaluations for the U-Net segmentations are as follows :")
    print()
    acc_value = accuracy_score(y_t,y_p)
    print(f"Accuracy score is: {acc_value}")

    jaccard=jaccard_score(y_t, y_p, average='macro')
    print(f"Jaccard score is: {jaccard}")

    dice_score = dice(y_p, y_t, k = True) 
    print ("Dice Similarity: {}".format(dice_score))

    

    tn, fp, fn, tp = confusion_matrix(y_t, y_p).ravel()
    print(tn, fp, fn, tp)

    dice_coff = 2*tp/(2*tp + fp + fn)
    jaccard_index = tp/(tp + fp + fn)
    print("Dice Cofficient : ", dice_coff)
    print("Jaccard Index : ", jaccard_index)

    print()
    print("Confusion Matrix:")
    print(confusion_matrix(y_t, y_p))
    print()
    precision = precision_score(y_t, y_p)
    print('Precision: %f' % precision)
    # recall: tp / (tp + fn)
    recall = recall_score(y_t, y_p)
    print('Recall: %f' % recall)
    # f1: 2 tp / (2 tp + fp + fn)
    f1 = f1_score(y_t, y_p)
    print('F1 score: %f' % f1)

# %%
# loading the model 
model = build_unet()
model.load_state_dict(torch.load('CrackSegment.pth'))
EvaluationOfSegmentation(r"Test_Images", r"Test_Masks")
# Out:
# ['119.jpg', '79.jpg', '106.jpg', '12.jpg', '54.jpg', '134.jpg', '124.jpg', '41.jpg', '75.jpg', '1.jpg']
# ['119.jpg', '79.jpg', '106.jpg', '12.jpg', '54.jpg', '134.jpg', '124.jpg', '41.jpg', '75.jpg', '1.jpg']
#
#  Various Evaluations for the U-Net segmentations are as follows :
#
# Accuracy score is: 0.9782089233398438
# Jaccard score is: 0.8930058311272909
# Dice Similarity: 0.895048981061636
# 580183 6595 7686 60896
# Dice Cofficient :  0.895048981061636
# Jaccard Index :  0.8100349841041808
#
# Confusion Matrix:
# [[580183   6595]
#  [  7686  60896]]
#
# Precision: 0.902283
# Recall: 0.887930
# F1 score: 0.895049

# %%
images_names = os.listdir(r"Test_Images")
Img_Testpath = r"Test_Images"
Mask_Testpath = r"Test_Masks"

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

test_results = Y_Pred(r"Test_Images")
for x in range(len(os.listdir(r"Test_Images"))):
#     print(x)
    Orgimg = plt.imread(os.path.join(Img_Testpath, images_names[x]))
    mask = plt.imread(os.path.join(Mask_Testpath, images_names[x]))
    
    p =test_results[x]
    pred=np.reshape(p, (256,256))
    plt.imsave(os.path.join(r"Results","res"+images_names[x]), pred, cmap=cm.gray)
    f, axarr = plt.subplots(1,3)
    axarr[0].imshow(Orgimg)
    axarr[1].imshow(mask)
    axarr[2].imshow(pred)
# Out:
# ['119.jpg', '79.jpg', '106.jpg', '12.jpg', '54.jpg', '134.jpg', '124.jpg', '41.jpg', '75.jpg', '1.jpg']

# %%
t_loss = []
v_loss = []
for i in range(len(train_losses)):
    t_loss.append(train_losses[i].cpu().detach().numpy())
    v_loss.append(validation_losses[i])

# %%
epoch = [i for i in range(num_epochs)]

import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 100
# plot the data 
plt.title('Training Loss Vs Validation Loss Plot') 
plt.ylim(0, 1)
plt.xlabel('Epochs')
plt.ylabel('BCELoss')
plt.plot(epoch, t_loss, color ='tab:blue') 
plt.plot(epoch, v_loss, color ='tab:orange') 
plt.legend(['Training Loss', 'Validation Loss'])
plt.savefig('VsLosses.png')
plt.savefig('VsLosses.pdf')
plt.show()
